# %%
#import Dependencies
import pandas as pd
import numpy as np
import tweepy
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import re
import csv
from textblob import TextBlob

# %%
from config import (consumer_key,consumer_secret,access_token,access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term
target_terms = ("@depressingmsgs", "@TheSuicideQuote", "@SuicidalQuotes6",
                "@SadQuotings","@BeyondBrokenDep","@depressedquxtes","@FakingYurSmile")

# %%
# Counter
# Variables for holding sentiments
sentiments = []

# Loop through all target users
for target in target_terms:
    counter = 1
#Loop through 100 tweets
    for x in range(5):

    #Get tweets from homefeed
        public_tweets = api.user_timeline(target, page=x,count=200)


        for tweet in public_tweets:
            compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]
            text=tweet['text']
            date=tweet['created_at']


 # Add sentiments for each tweet into a list
            sentiments.append({"Tweets":text,
                       "Positive": pos,
                       "Negative": neg})

# Add to counter 
            counter += 1

# %%
# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.shape
# Out:
# (4775, 3)

# %%
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
sentiments_pd['tidy_tweet'] = np.vectorize(remove_pattern)(sentiments_pd['Tweets'], "@[\w]*") 
sentiments_pd.shape
# Out:
# (4775, 4)

# %%
def f(row):
    if (row['Positive']>row['Negative']):
        val = "Positive"
        
    elif (row['Positive']<row['Negative']):
        val = "Negative"
    else:
        val = "Neutral"
    return val

# %%
sentiments_pd['Sentiment'] = sentiments_pd.apply(f, axis=1)

# %%
sentiments_pd['tidy_tweet'] = sentiments_pd['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")

# %%
sentiments_pd
# Out:
#       Negative  Positive                                             Tweets  \
# 0        0.000     0.000                                @gaterhole its 2019
# 1        0.366     0.091  depression is not a phase\nit’s a disease.\n\n...
# 2        0.369     0.000  @CraigDurhamJr nah not really, just glad Chris...
# 3        0.098     0.094  @CraigDurhamJr Yeah I always struggle at this ...
# 4        0.110     0.200  @CraigDurhamJr So sorry to hear that, its good...
# 5        0.000     0.627  @CraigDurhamJr Merry Christmas hun, hope you h...
# 6        0.239     0.131  i’m ashamed of myself because i know i should ...
# 7        0.000     0.000                   @fxding_stxr totally understand.
# 8        0.000     0.242  @KittyCat1603 @Twitter oh, that makes sense! t...
# 9        0.000     0.452  @oldlostsock i'm already following for the las...
# 10       0.000     0.394                         @spacelyast pls explain? 🙄
# 11       0.000     0.524  @oldlostsock @Lib_fallenangel @KarenKts11 @The...
# 12       0.000     0.517  @Lib_fallenangel @oldlostsock @beyondxdarkness...
# 13       0.158     0.073  @oldlostsock @beyondxdarkness just saw this no...
# 14       0.000     0.000    @kdc_goth I was thinking the same thing because
# 15       0.204     0.426         @kdc_goth Hi sweetheart! I've missed you,💜
# 16       0.235     0.175  @stareater44 Depression isn't a CHOICE! becami...
# 17       0.625     0.000          @stareater44 oh,... okay..yep no worries.
# 18       0.167     0.000  i’m used to it. \n\ni’m used to being left out...
# 19       0.000     0.552           @JustJennifer97 my pleasure sweetheart.💜
# 20       0.365     0.000       @JustJennifer97 It's their loss sweetheart.💜
# 21       0.316     0.173  @CraigDurhamJr Everything is difficult when yo...
# 22       0.000     0.000                         @melancholiia_x beautiful💜
# 23       0.297     0.047  i'm just so tired of this. my body is tired, m...
# 24       0.544     0.000                     @iamjeanius how fxcking rude!!
# 25       0.000     0.000          “are you okay?”\nme: “no, but it’s okay.”
# 26       0.000     0.000                                 @CraigDurhamJr mєє
# 27       0.000     0.000  @melancholiia_x @CrxzyBitxh so һѧppʏ ғoя ʏou һuň💜
# 28       0.000     0.000  @LifeOfALez ţһѧňҡ ʏou sɰєєţһєѧяţ, mєѧňs ţһє ɰo...
# 4746  Don t judge me when you don t know anything ab...   Neutral
# 4747  Sometimes the best way to solve a problem is t...  Positive
# 4748  It s amazing what you can hide just by putting...  Positive
# 4749  I was praying that you and me might end up tog...  Positive
# 4750  RT   I wish I could explain to you how I felt ...  Positive
# 4751                             http   t co dUzVnqpqQj   Neutral
# 4752  Why fall in love when u can fall on the floor ...  Positive
# 4753                  Depression is a dark lonely place  Negative
# 4754  We stop looking for monsters under our beds wh...  Negative
# 4755  The people with the best advice are usually th...  Positive
# 4756  Pretend like everything s all right act its al...  Positive
# 4757                             http   t co gUpPhRO qL   Neutral
# 4758  It s hard to pretend you dont love someone whe...  Negative
# 4759          I m not mad I m hurt there s a difference  Positive
# 4760                             http   t co IiY kA dJ    Neutral
# 4761       The nicer you re  the easier you ll get hurt  Positive
# 4762  At night I can t sleep in the morning I can t ...   Neutral
# 4763                             http   t co  WwqwQXljC   Neutral
# 4764  I don t tell anyone about my feelings so if I ...  Positive
# 4765                  Just once  http   t co  rxntFZ Jd   Neutral
# 4766     I may be quiet  but I have so much on my mind    Neutral
# 4767                             http   t co X GmdrHimE   Neutral
# 4768  You can close your eyes to the things you don ...   Neutral
# 4769  Just because she s smiling this morning doesn ...  Positive
# 4770  Don t judge someone for their choices when you...   Neutral
# 4771  Sometimes in life we just need someone who wil...   Neutral
# 4772  Sooner or later all the things you ve bottled ...   Neutral
# 4773  There comes a point in life where you can t ta...   Neutral
# 4774  It s sad when you get hurt so much that you sa...  Negative
#
# [4775 rows x 5 columns]

# %%
new_df = sentiments_pd[sentiments_pd.Sentiment != 'Neutral']

# %%
depression_text=new_df.drop(['Positive','Negative','Tweets'],axis=1)

# %%
depression_text.head(25)
# Out:
#                                            tidy_tweet Sentiment
# 1   depression is not a phase it s a disease   it ...  Negative
# 2        nah not really  just glad Christmas is over   Negative
# 3    Yeah I always struggle at this time of year  ...  Negative
# 4    So sorry to hear that  its good to be around ...  Positive
# 5    Merry Christmas hun  hope you had a wonderful...  Positive
# 6   i m ashamed of myself because i know i should ...  Negative
# 8     oh  that makes sense  thanks for letting me ...  Positive
# 9    i m already following for the last   amazing ...  Positive
# 10                                     pls explain     Positive
# 11      congratulations hope you re proud of your ...  Positive
# 12     You are so sweet  with a beautiful soul  ho...  Positive
# 13    just saw this now  I m doing okay  it s the ...  Negative
# 15                   Hi sweetheart  I ve missed you    Positive
# 16   Depression isn t a CHOICE  becaming more educ...  Negative
# 17                       oh     okay  yep no worries   Negative
# 18  i m used to it    i m used to being left out  ...  Negative
# 19                           my pleasure sweetheart    Positive
# 20                       It s their loss sweetheart    Negative
# 21   Everything is difficult when you re in a dark...  Negative
# 23  i m just so tired of this  my body is tired  m...  Negative
# 24                                 how fxcking rude    Negative
# 29  i am constantly torn between wanting to fix my...  Negative
# 32   yep me too  that s why I don t tweet much any...  Positive
# 33   Those how ever are good for your health  They...  Positive
# 34  i m sick of making things worse  i m sick of b...  Negative

# %%
depression_text.to_csv("depression_text.txt", encoding="utf-8", sep=',',index=False)

# %%
depression_text.to_csv("depression_text.csv", encoding="utf-8", sep=',',index=False)

# %%
# !jupyter nbconvert --to script Sentiment_Analysis-mentalhealth.ipynb
# Out:
# [NbConvertApp] Converting notebook Sentiment_Analysis-mentalhealth.ipynb to script
# [NbConvertApp] Writing 2935 bytes to Sentiment_Analysis-mentalhealth.py
